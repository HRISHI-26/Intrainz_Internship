# %% [markdown]
# #Credit Card Fraud Detection

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %%
#Loading Dataset
data = pd.read_csv("creditcard.csv")

# %%
#first five rows of the dataset
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#last 5 rows
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#Checking the number of missing values in each column

data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transcations and fraudulent transactions
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %%
#seperating data for analysis
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#Statistical measures of data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# As per above result we have high variations so we are Creating new dataset with uniformity

# %%
#compare the values for both transactions
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset ccontaining similar distribution of normal transactions and fraudulent transactions

# %%
#taking random 492 transactions to balance with fraudulent in sample dataset we create
legit_sample = legit.sample(n=492)

# %%
#concatenate two DataFrames to create new dataset

new_dataset = pd.concat([legit_sample, fraud], axis=0) #axis = 0 --> row

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 260442  159559.0  1.969066 -0.575715 -0.302902  0.529832 -0.957067 -0.548696
# 164689  116916.0 -0.698713  0.337853 -0.340922 -0.765439  1.242853  0.926806
# 54373    46419.0  1.282946  1.386493 -1.766863  1.517445  1.201401 -1.513565
# 152256   97178.0 -1.130980  2.052570 -1.817490 -1.203895  1.033925 -0.770603
# 195161  130926.0 -1.243469  0.493802 -0.144025 -2.800541 -1.051577 -0.486117
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 260442 -0.762194  0.089632  1.804291  ...  0.170136  0.650224  0.143494
# 164689  0.600030  0.528495 -0.022701  ...  0.478743  1.656958  0.143082
# 54373   0.859709 -0.433139 -0.620904  ... -0.227125 -0.484654 -0.286951
# 152256  0.743747  0.558252  0.617462  ...  0.146682  0.706816 -0.142624
# 195161  0.356239  0.413615 -3.353234  ... -0.224264 -0.623534 -0.119672
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97515.902439  0.117976 -0.092928 -0.041198 -0.011687 -0.035168
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.021463 -0.013129  0.070624 -0.035212  ...  0.006495  0.010127
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23      V24       V25       V26       V27       V28  \
# Class
# 0     -0.030558  0.003116 -0.03592 -0.014382 -0.004452  0.009716  0.005989
# 1      0.014049 -0.040308 -0.10513  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       95.400793
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the Data into features and targets

# %%
X = new_dataset.drop(columns = 'Class', axis=1) #axis == 1 --> column
Y = new_dataset['Class']

# %%
X #No class column
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 260442  159559.0  1.969066 -0.575715 -0.302902  0.529832 -0.957067 -0.548696
# 164689  116916.0 -0.698713  0.337853 -0.340922 -0.765439  1.242853  0.926806
# 54373    46419.0  1.282946  1.386493 -1.766863  1.517445  1.201401 -1.513565
# 152256   97178.0 -1.130980  2.052570 -1.817490 -1.203895  1.033925 -0.770603
# 195161  130926.0 -1.243469  0.493802 -0.144025 -2.800541 -1.051577 -0.486117
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# Split into training and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X_train, X_train.shape, X_test.shape)
# Out:
#             Time         V1        V2         V3        V4         V5  \
# 100623   67571.0  -0.758469 -0.045410  -0.168438 -1.313275  -1.901763
# 101116   67730.0  -0.482143 -0.588716   2.965751 -1.448336  -0.947291
# 107613   70521.0  -0.489837  1.224335   1.486311  0.050315  -0.040681
# 74723    55720.0  -0.664328 -0.543185   0.773031 -2.546969  -0.773376
# 196179  131393.0  -0.901814 -0.393354   0.223837 -1.764034  -0.173358
# ...          ...        ...       ...        ...       ...        ...
# 40299    40180.0  -1.540349  1.372062   0.961546 -1.308589  -1.036786
# 232410  147158.0  -0.493231  0.110828   0.595539 -2.267556   0.272888
# 223618  143456.0  -2.006582  3.676577  -5.463811  7.232058  -1.627859
# 43061    41353.0 -15.020981  8.075240 -16.298091  5.664820 -11.918153
# 195605  131142.0   2.167984 -0.613357  -1.801759 -0.431077  -0.041201
#
#               V6         V7        V8        V9  ...       V20       V21  \
# ...

# %% [markdown]
# Model Training - Logistic Regression

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
#Accuracy score
X_train_prediction = model.predict(X_train)
train_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print(train_accuracy)
# Out:
# 0.9440914866581956

# %%
#Accuracy on test data
X_test_prediction = model.predict(X_test)
test_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print(test_accuracy)
# Out:
# 0.9390862944162437

# %% [markdown]
# If the train_accuracy & test_accuracy is almost equal then its a good model
